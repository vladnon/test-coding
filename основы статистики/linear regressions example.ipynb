# %% [markdown]
# Task: Проанализировать как связаны две переменные, опровергнуть или принять нулевую гипотезу и предсказать значение переменной на обученной модели

# %% [markdown]
# Import all modules

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Read data

# %%
df = pd.read_csv("./основы статистики/states.csv")
y = df["poverty"].to_numpy().reshape(-1, 1)
x = df["hs_grad"].to_numpy().reshape(-1, 1)
test_y = pd.DataFrame([62])

# %% [markdown]
# Model

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-0.62121672]])

# %%
model.intercept_
# Out:
# array([64.78096577])

# %%
model.predict(test_y)
# Out:
# array([[26.26552927]])

# %% [markdown]
# Visualisation

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x), color="red")
plt.ylabel("Бедность (%)")
plt.xlabel("Среднее образование (%)")
plt.title("Связь бедности со уровнем образования")
plt.show()
